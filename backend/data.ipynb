# %%
INSERT INTO users (
  id, 
  email, 
  password_hash, 
  role, 
  is_active, 
  email_verified, 
  created_at, 
  updated_at
)
VALUES (
  'a1b2c3d4-e5f6-7a8b-9c0d-1e2f3a4b5c6d', -- Exemple: 'a1b2c3d4-e5f6-7a8b-9c0d-1e2f3a4b5c6d'
  'admin@rehoboth.org',                    -- E-mail de l'admin
  'supabase_managed',                      -- Hash (géré via Supabase Auth)
  'SUPER_ADMIN',                           -- Rôle d'administration suprême
  true,                                    -- Actif
  true,                                    -- E-mail validé
  NOW(), 
  NOW()
)
ON CONFLICT (id) DO UPDATE 
SET role = 'SUPER_ADMIN';
